# %%
template = """
FROM prolocutor/docker-python-sqlite:3.12

RUN cd /tmp/sqlite-autoconf-3120200 \                                                                    
        && ./configure --prefix=/usr --disable-static \                                                  
                CFLAGS="-g {{ flag -}}" \
        && make \                                                                                        
        && make install \                                                                                
        && rm -r /tmp/*                                                                                  


RUN find /usr/local -depth \
		\( \
		    \( -type d -a -name test -o -name tests \) \
		    -o \
		    \( -type f -a -name '*.pyc' -o -name '*.pyo' \) \
		\) -exec rm -rf '{}' + \
	&& runDeps="$( \
		scanelf --needed --nobanner --recursive /usr/local \
			| awk '{ gsub(/,/, "\nso:", $2); print "so:" $2 }' \
			| sort -u \
			| xargs -r apk info --installed \
			| sort -u \
	)" \
	&& apk add --virtual .python-rundeps $runDeps \
	&& apk del .build-deps \
	&& rm -rf /usr/src/python ~/.cache

CMD ["python3"]

"""
with open("Dockerfile.jinja2","w") as f:
    f.write(template)

# %%
tree = {"sqlite3.12":"./sqlite3.12"}

trunk = {"Os":"-Os",
         "O2":"-O2",
        "debug":"-DSQLITE_DEBUG"}

available_flags = {"fts5":"-DSQLITE_ENABLE_FTS5",
                   "rtree":"-DSQLITE_ENABLE_RTREE",
                   "column-metadata":"-DSQLITE_ENABLE_COLUMN_METADATA",
                   "json1":"-DSQLITE_ENABLE_JSON1"}
import os
from itertools import permutations
root = "./sqlite3.12/"

length = len(available_flags)

dockerfile_dir = []
for root in tree.values():
    for p in permutations(available_flags):
        for item in trunk:
            d = os.path.join(root,item,"/".join(p))
            try: os.makedirs(d)
            except: pass
            dockerfile_dir.append(d)
dockerfile_dir
# Out:
# ['./sqlite3.12/Os/column-metadata/fts5/json1/rtree',
#  './sqlite3.12/O2/column-metadata/fts5/json1/rtree',
#  './sqlite3.12/debug/column-metadata/fts5/json1/rtree',
#  './sqlite3.12/Os/column-metadata/fts5/rtree/json1',
#  './sqlite3.12/O2/column-metadata/fts5/rtree/json1',
#  './sqlite3.12/debug/column-metadata/fts5/rtree/json1',
#  './sqlite3.12/Os/column-metadata/json1/fts5/rtree',
#  './sqlite3.12/O2/column-metadata/json1/fts5/rtree',
#  './sqlite3.12/debug/column-metadata/json1/fts5/rtree',
#  './sqlite3.12/Os/column-metadata/json1/rtree/fts5',
#  './sqlite3.12/O2/column-metadata/json1/rtree/fts5',
#  './sqlite3.12/debug/column-metadata/json1/rtree/fts5',
#  './sqlite3.12/Os/column-metadata/rtree/fts5/json1',
#  './sqlite3.12/O2/column-metadata/rtree/fts5/json1',
#  './sqlite3.12/debug/column-metadata/rtree/fts5/json1',
#  './sqlite3.12/Os/column-metadata/rtree/json1/fts5',
#  './sqlite3.12/O2/column-metadata/rtree/json1/fts5',
#  './sqlite3.12/debug/column-metadata/rtree/json1/fts5',
#  './sqlite3.12/Os/fts5/column-metadata/json1/rtree',
#  './sqlite3.12/O2/fts5/column-metadata/json1/rtree',
#  './sqlite3.12/debug/fts5/column-metadata/json1/rtree',
#  './sqlite3.12/Os/fts5/column-metadata/rtree/json1',
#  './sqlite3.12/O2/fts5/column-metadata/rtree/json1',
#  './sqlite3.12/debug/fts5/column-metadata/rtree/json1',
#  './sqlite3.12/Os/fts5/json1/column-metadata/rtree',
#  './sqlite3.12/O2/fts5/json1/column-metadata/rtree',
#  './sqlite3.12/debug/fts5/json1/column-metadata/rtree',
#  './sqlite3.12/Os/fts5/json1/rtree/column-metadata',
#  './sqlite3.12/O2/fts5/json1/rtree/column-metadata',
#  './sqlite3.12/debug/fts5/json1/rtree/column-metadata',
#  './sqlite3.12/Os/fts5/rtree/column-metadata/json1',
#  './sqlite3.12/O2/fts5/rtree/column-metadata/json1',
#  './sqlite3.12/debug/fts5/rtree/column-metadata/json1',
#  './sqlite3.12/Os/fts5/rtree/json1/column-metadata',
#  './sqlite3.12/O2/fts5/rtree/json1/column-metadata',
#  './sqlite3.12/debug/fts5/rtree/json1/column-metadata',
#  './sqlite3.12/Os/json1/column-metadata/fts5/rtree',
#  './sqlite3.12/O2/json1/column-metadata/fts5/rtree',
#  './sqlite3.12/debug/json1/column-metadata/fts5/rtree',
#  './sqlite3.12/Os/json1/column-metadata/rtree/fts5',
#  './sqlite3.12/O2/json1/column-metadata/rtree/fts5',
#  './sqlite3.12/debug/json1/column-metadata/rtree/fts5',
#  './sqlite3.12/Os/json1/fts5/column-metadata/rtree',
#  './sqlite3.12/O2/json1/fts5/column-metadata/rtree',
#  './sqlite3.12/debug/json1/fts5/column-metadata/rtree',
#  './sqlite3.12/Os/json1/fts5/rtree/column-metadata',
#  './sqlite3.12/O2/json1/fts5/rtree/column-metadata',
#  './sqlite3.12/debug/json1/fts5/rtree/column-metadata',
#  './sqlite3.12/Os/json1/rtree/column-metadata/fts5',
#  './sqlite3.12/O2/json1/rtree/column-metadata/fts5',
#  './sqlite3.12/debug/json1/rtree/column-metadata/fts5',
#  './sqlite3.12/Os/json1/rtree/fts5/column-metadata',
#  './sqlite3.12/O2/json1/rtree/fts5/column-metadata',
#  './sqlite3.12/debug/json1/rtree/fts5/column-metadata',
#  './sqlite3.12/Os/rtree/column-metadata/fts5/json1',
#  './sqlite3.12/O2/rtree/column-metadata/fts5/json1',
#  './sqlite3.12/debug/rtree/column-metadata/fts5/json1',
#  './sqlite3.12/Os/rtree/column-metadata/json1/fts5',
#  './sqlite3.12/O2/rtree/column-metadata/json1/fts5',
#  './sqlite3.12/debug/rtree/column-metadata/json1/fts5',
#  './sqlite3.12/Os/rtree/fts5/column-metadata/json1',
#  './sqlite3.12/O2/rtree/fts5/column-metadata/json1',
#  './sqlite3.12/debug/rtree/fts5/column-metadata/json1',
#  './sqlite3.12/Os/rtree/fts5/json1/column-metadata',
#  './sqlite3.12/O2/rtree/fts5/json1/column-metadata',
#  './sqlite3.12/debug/rtree/fts5/json1/column-metadata',
#  './sqlite3.12/Os/rtree/json1/column-metadata/fts5',
#  './sqlite3.12/O2/rtree/json1/column-metadata/fts5',
#  './sqlite3.12/debug/rtree/json1/column-metadata/fts5',
#  './sqlite3.12/Os/rtree/json1/fts5/column-metadata',
#  './sqlite3.12/O2/rtree/json1/fts5/column-metadata',
#  './sqlite3.12/debug/rtree/json1/fts5/column-metadata']

# %%
flag_combinations = []

for L in range(0, len(available_flags)+1):
    for subset in itertools.combinations(available_flags, L):
        for k,v in trunk.items():
            flag_combinations.append(sorted(subset+(k,)))
            
flag_combinations
# Out:
# [['Os'],
#  ['O2'],
#  ['debug'],
#  ['Os', 'column-metadata'],
#  ['O2', 'column-metadata'],
#  ['column-metadata', 'debug'],
#  ['Os', 'fts5'],
#  ['O2', 'fts5'],
#  ['debug', 'fts5'],
#  ['Os', 'json1'],
#  ['O2', 'json1'],
#  ['debug', 'json1'],
#  ['Os', 'rtree'],
#  ['O2', 'rtree'],
#  ['debug', 'rtree'],
#  ['Os', 'column-metadata', 'fts5'],
#  ['O2', 'column-metadata', 'fts5'],
#  ['column-metadata', 'debug', 'fts5'],
#  ['Os', 'column-metadata', 'json1'],
#  ['O2', 'column-metadata', 'json1'],
#  ['column-metadata', 'debug', 'json1'],
#  ['Os', 'column-metadata', 'rtree'],
#  ['O2', 'column-metadata', 'rtree'],
#  ['column-metadata', 'debug', 'rtree'],
#  ['Os', 'fts5', 'json1'],
#  ['O2', 'fts5', 'json1'],
#  ['debug', 'fts5', 'json1'],
#  ['Os', 'fts5', 'rtree'],
#  ['O2', 'fts5', 'rtree'],
#  ['debug', 'fts5', 'rtree'],
#  ['Os', 'json1', 'rtree'],
#  ['O2', 'json1', 'rtree'],
#  ['debug', 'json1', 'rtree'],
#  ['Os', 'column-metadata', 'fts5', 'json1'],
#  ['O2', 'column-metadata', 'fts5', 'json1'],
#  ['column-metadata', 'debug', 'fts5', 'json1'],
#  ['Os', 'column-metadata', 'fts5', 'rtree'],
#  ['O2', 'column-metadata', 'fts5', 'rtree'],
#  ['column-metadata', 'debug', 'fts5', 'rtree'],
#  ['Os', 'column-metadata', 'json1', 'rtree'],
#  ['O2', 'column-metadata', 'json1', 'rtree'],
#  ['column-metadata', 'debug', 'json1', 'rtree'],
#  ['Os', 'fts5', 'json1', 'rtree'],
#  ['O2', 'fts5', 'json1', 'rtree'],
#  ['debug', 'fts5', 'json1', 'rtree'],
#  ['Os', 'column-metadata', 'fts5', 'json1', 'rtree'],
#  ['O2', 'column-metadata', 'fts5', 'json1', 'rtree'],
#  ['column-metadata', 'debug', 'fts5', 'json1', 'rtree']]

# %%
all_flags = available_flags.update(trunk)
print(available_flags)
# Out:
# {'O2': '-O2', 'debug': '-DSQLITE_DEBUG', 'rtree': '-DSQLITE_ENABLE_RTREE', 'column-metadata': '-DSQLITE_ENABLE_COLUMN_METADATA', 'fts5': '-DSQLITE_ENABLE_FTS5', 'Os': '-Os', 'json1': '-DSQLITE_ENABLE_JSON1'}

# %%
from jinja2 import Template, Environment, FileSystemLoader
import collections

#Everything is a template
obreros_env = Environment(loader=FileSystemLoader('.'))

for k,v in tree.items():
    for root, subdirs, files in os.walk(v):
        root_flags = root.replace(v,'').split('/')[1:]

        for flags in flag_combinations:
            if collections.Counter(root_flags) == collections.Counter(flags):
                flag = " ".join([available_flags[flag] for flag in flags])
                print(flag)
                obreros_template = obreros_env.get_template('Dockerfile.jinja2').render(flag=flag)
                Dockerfile = root+"/"+"Dockerfile"
                print(Dockerfile)
                with open(Dockerfile, "w") as f:
                    f.write(obreros_template)
# Out:
# -O2
# ./sqlite3.12/O2/Dockerfile
# -O2 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/rtree/Dockerfile
# -O2 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/rtree/json1/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/rtree/json1/column-metadata/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/rtree/json1/column-metadata/fts5/Dockerfile
# -O2 -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/rtree/json1/fts5/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/rtree/json1/fts5/column-metadata/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/rtree/column-metadata/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/rtree/column-metadata/json1/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/rtree/column-metadata/json1/fts5/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/rtree/column-metadata/fts5/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/rtree/column-metadata/fts5/json1/Dockerfile
# -O2 -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/rtree/fts5/Dockerfile
# -O2 -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/rtree/fts5/json1/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/rtree/fts5/json1/column-metadata/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/rtree/fts5/column-metadata/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/rtree/fts5/column-metadata/json1/Dockerfile
# -O2 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/O2/json1/Dockerfile
# -O2 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/json1/rtree/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/json1/rtree/column-metadata/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/json1/rtree/column-metadata/fts5/Dockerfile
# -O2 -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/json1/rtree/fts5/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/json1/rtree/fts5/column-metadata/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/O2/json1/column-metadata/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/json1/column-metadata/rtree/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/json1/column-metadata/rtree/fts5/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/O2/json1/column-metadata/fts5/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/json1/column-metadata/fts5/rtree/Dockerfile
# -O2 -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/O2/json1/fts5/Dockerfile
# -O2 -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/json1/fts5/rtree/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/json1/fts5/rtree/column-metadata/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/O2/json1/fts5/column-metadata/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/json1/fts5/column-metadata/rtree/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA
# ./sqlite3.12/O2/column-metadata/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/column-metadata/rtree/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/column-metadata/rtree/json1/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/column-metadata/rtree/json1/fts5/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/column-metadata/rtree/fts5/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/column-metadata/rtree/fts5/json1/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/O2/column-metadata/json1/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/column-metadata/json1/rtree/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/column-metadata/json1/rtree/fts5/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/O2/column-metadata/json1/fts5/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/column-metadata/json1/fts5/rtree/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5
# ./sqlite3.12/O2/column-metadata/fts5/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/column-metadata/fts5/rtree/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/column-metadata/fts5/rtree/json1/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/O2/column-metadata/fts5/json1/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/column-metadata/fts5/json1/rtree/Dockerfile
# -O2 -DSQLITE_ENABLE_FTS5
# ./sqlite3.12/O2/fts5/Dockerfile
# -O2 -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/fts5/rtree/Dockerfile
# -O2 -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/fts5/rtree/json1/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/fts5/rtree/json1/column-metadata/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/fts5/rtree/column-metadata/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/fts5/rtree/column-metadata/json1/Dockerfile
# -O2 -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/O2/fts5/json1/Dockerfile
# -O2 -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/fts5/json1/rtree/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/fts5/json1/rtree/column-metadata/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/O2/fts5/json1/column-metadata/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/fts5/json1/column-metadata/rtree/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5
# ./sqlite3.12/O2/fts5/column-metadata/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/fts5/column-metadata/rtree/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/fts5/column-metadata/rtree/json1/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/O2/fts5/column-metadata/json1/Dockerfile
# -O2 -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/O2/fts5/column-metadata/json1/rtree/Dockerfile
# -DSQLITE_DEBUG
# ./sqlite3.12/debug/Dockerfile
# -DSQLITE_DEBUG -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/rtree/Dockerfile
# -DSQLITE_DEBUG -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/rtree/json1/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/rtree/json1/column-metadata/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/rtree/json1/column-metadata/fts5/Dockerfile
# -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/rtree/json1/fts5/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/rtree/json1/fts5/column-metadata/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/rtree/column-metadata/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/rtree/column-metadata/json1/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/rtree/column-metadata/json1/fts5/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/rtree/column-metadata/fts5/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/rtree/column-metadata/fts5/json1/Dockerfile
# -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/rtree/fts5/Dockerfile
# -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/rtree/fts5/json1/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/rtree/fts5/json1/column-metadata/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/rtree/fts5/column-metadata/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/rtree/fts5/column-metadata/json1/Dockerfile
# -DSQLITE_DEBUG -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/debug/json1/Dockerfile
# -DSQLITE_DEBUG -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/json1/rtree/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/json1/rtree/column-metadata/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/json1/rtree/column-metadata/fts5/Dockerfile
# -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/json1/rtree/fts5/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/json1/rtree/fts5/column-metadata/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/debug/json1/column-metadata/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/json1/column-metadata/rtree/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/json1/column-metadata/rtree/fts5/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/debug/json1/column-metadata/fts5/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/json1/column-metadata/fts5/rtree/Dockerfile
# -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/debug/json1/fts5/Dockerfile
# -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/json1/fts5/rtree/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/json1/fts5/rtree/column-metadata/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/debug/json1/fts5/column-metadata/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/json1/fts5/column-metadata/rtree/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG
# ./sqlite3.12/debug/column-metadata/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/column-metadata/rtree/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/column-metadata/rtree/json1/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/column-metadata/rtree/json1/fts5/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/column-metadata/rtree/fts5/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/column-metadata/rtree/fts5/json1/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/debug/column-metadata/json1/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/column-metadata/json1/rtree/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/column-metadata/json1/rtree/fts5/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/debug/column-metadata/json1/fts5/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/column-metadata/json1/fts5/rtree/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5
# ./sqlite3.12/debug/column-metadata/fts5/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/column-metadata/fts5/rtree/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/column-metadata/fts5/rtree/json1/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/debug/column-metadata/fts5/json1/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/column-metadata/fts5/json1/rtree/Dockerfile
# -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5
# ./sqlite3.12/debug/fts5/Dockerfile
# -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/fts5/rtree/Dockerfile
# -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/fts5/rtree/json1/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/fts5/rtree/json1/column-metadata/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/fts5/rtree/column-metadata/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/fts5/rtree/column-metadata/json1/Dockerfile
# -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/debug/fts5/json1/Dockerfile
# -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/fts5/json1/rtree/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/fts5/json1/rtree/column-metadata/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/debug/fts5/json1/column-metadata/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/fts5/json1/column-metadata/rtree/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5
# ./sqlite3.12/debug/fts5/column-metadata/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/fts5/column-metadata/rtree/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/fts5/column-metadata/rtree/json1/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/debug/fts5/column-metadata/json1/Dockerfile
# -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_DEBUG -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/debug/fts5/column-metadata/json1/rtree/Dockerfile
# -Os
# ./sqlite3.12/Os/Dockerfile
# -Os -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/rtree/Dockerfile
# -Os -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/rtree/json1/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/rtree/json1/column-metadata/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/rtree/json1/column-metadata/fts5/Dockerfile
# -Os -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/rtree/json1/fts5/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/rtree/json1/fts5/column-metadata/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/rtree/column-metadata/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/rtree/column-metadata/json1/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/rtree/column-metadata/json1/fts5/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/rtree/column-metadata/fts5/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/rtree/column-metadata/fts5/json1/Dockerfile
# -Os -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/rtree/fts5/Dockerfile
# -Os -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/rtree/fts5/json1/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/rtree/fts5/json1/column-metadata/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/rtree/fts5/column-metadata/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/rtree/fts5/column-metadata/json1/Dockerfile
# -Os -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/Os/json1/Dockerfile
# -Os -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/json1/rtree/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/json1/rtree/column-metadata/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/json1/rtree/column-metadata/fts5/Dockerfile
# -Os -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/json1/rtree/fts5/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/json1/rtree/fts5/column-metadata/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/Os/json1/column-metadata/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/json1/column-metadata/rtree/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/json1/column-metadata/rtree/fts5/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/Os/json1/column-metadata/fts5/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/json1/column-metadata/fts5/rtree/Dockerfile
# -Os -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/Os/json1/fts5/Dockerfile
# -Os -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/json1/fts5/rtree/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/json1/fts5/rtree/column-metadata/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/Os/json1/fts5/column-metadata/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/json1/fts5/column-metadata/rtree/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA
# ./sqlite3.12/Os/column-metadata/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/column-metadata/rtree/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/column-metadata/rtree/json1/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/column-metadata/rtree/json1/fts5/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/column-metadata/rtree/fts5/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/column-metadata/rtree/fts5/json1/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/Os/column-metadata/json1/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/column-metadata/json1/rtree/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/column-metadata/json1/rtree/fts5/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/Os/column-metadata/json1/fts5/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/column-metadata/json1/fts5/rtree/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5
# ./sqlite3.12/Os/column-metadata/fts5/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/column-metadata/fts5/rtree/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/column-metadata/fts5/rtree/json1/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/Os/column-metadata/fts5/json1/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/column-metadata/fts5/json1/rtree/Dockerfile
# -Os -DSQLITE_ENABLE_FTS5
# ./sqlite3.12/Os/fts5/Dockerfile
# -Os -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/fts5/rtree/Dockerfile
# -Os -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/fts5/rtree/json1/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/fts5/rtree/json1/column-metadata/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/fts5/rtree/column-metadata/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/fts5/rtree/column-metadata/json1/Dockerfile
# -Os -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/Os/fts5/json1/Dockerfile
# -Os -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/fts5/json1/rtree/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/fts5/json1/rtree/column-metadata/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/Os/fts5/json1/column-metadata/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/fts5/json1/column-metadata/rtree/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5
# ./sqlite3.12/Os/fts5/column-metadata/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/fts5/column-metadata/rtree/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/fts5/column-metadata/rtree/json1/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1
# ./sqlite3.12/Os/fts5/column-metadata/json1/Dockerfile
# -Os -DSQLITE_ENABLE_COLUMN_METADATA -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_RTREE
# ./sqlite3.12/Os/fts5/column-metadata/json1/rtree/Dockerfile
